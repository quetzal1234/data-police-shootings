# %% [markdown]
# ## Final Project, Part 1
# Washington Post Police Shootings Database

# %% [markdown]
# #### From the Readme (https://github.com/washingtonpost/data-police-shootings):
#
# In 2015, The Post began tracking more than a dozen details about each killing — including the race of the deceased, the circumstances of the shooting, whether the person was armed and whether the person was experiencing a mental-health crisis — by culling local news reports, law enforcement websites and social media, and by monitoring independent databases such as Killed by Police and Fatal Encounters. The Post conducted additional reporting in many cases.
#
# The Post is documenting only those shootings in which a police officer, in the line of duty, shoots and kills a civilian — the circumstances that most closely parallel the 2014 killing of Michael Brown in Ferguson, Mo., which began the protest movement culminating in Black Lives Matter and an increased focus on police accountability nationwide. The Post is not tracking deaths of people in police custody, fatal shootings by off-duty officers or non-shooting deaths.
#
# The FBI and the Centers for Disease Control and Prevention log fatal shootings by police, but officials acknowledge that their data is incomplete. Since 2015, The Post has documented more than twice as many fatal shootings by police as recorded on average annually.

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv("fatal-police-shootings-data.csv")
df
# Out:
#         id                    name        date   manner_of_death       armed  \
# 0        3              Tim Elliot  2015-01-02              shot         gun
# 1        4        Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5      John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8         Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9       Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                     ...         ...               ...         ...
# 5758  6296          Stephen Campos  2020-11-07              shot         gun
# 5759  6297  Jesse James Kale Brown  2020-11-07  shot and Tasered       knife
# 5760  6292   Rodriguez Duandre Pam  2020-11-08              shot         gun
# 5761  6295         Terry David Fox  2020-11-08              shot         gun
# 5762  6293                     NaN  2020-11-09              shot         gun
#
#        age gender race              city state  signs_of_mental_illness  \
# 0     53.0      M    A           Shelton    WA                     True
# 1     47.0      M    W             Aloha    OR                    False
# 2     23.0      M    H           Wichita    KS                    False
# 3     32.0      M    W     San Francisco    CA                     True
# 4     39.0      M    H             Evans    CO                    False
# ...    ...    ...  ...               ...   ...                      ...
# 5758  43.0      M  NaN           Lilburn    GA                    False
# 5759  34.0      M  NaN          Missoula    MT                    False
# 5760  33.0      M  NaN        Evansville    IN                    False
# 5761  58.0      M  NaN  Kingston Springs    TN                    False
# 5762   NaN      M  NaN         Baltimore    MD                    False
#
#      threat_level         flee  body_camera  longitude  latitude  \
# 0          attack  Not fleeing        False   -123.122    47.247
# 1          attack  Not fleeing        False   -122.892    45.487
# 2           other  Not fleeing        False    -97.281    37.695
# 3          attack  Not fleeing        False   -122.422    37.763
# 4          attack  Not fleeing        False   -104.692    40.384
# ...           ...          ...          ...        ...       ...
# 5758       attack  Not fleeing        False    -84.077    33.846
# 5759       attack          NaN        False   -114.035    46.874
# 5760        other          NaN         True    -87.567    37.969
# 5761        other  Not fleeing        False    -87.164    36.055
# 5762       attack  Not fleeing        False    -76.671    39.308
#
#       is_geocoding_exact
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 5758                True
# 5759                True
# 5760                True
# 5761                True
# 5762                True
#
# [5763 rows x 17 columns]

# %%
count = df.groupby(["manner_of_death"])["id"].count()
count.plot(kind="bar")

# %%
df.groupby(["race"])["id"].count().plot(kind="pie")

# %% [markdown]
# ### Discussion
# *What is the "name" of the dataset?*
#
# "Fatal Force"
#
# *Where did you obtain it?*
#
# From the Washington Post's github page.
#
# *Where can we obtain it? (i.e., URL)*
#
# https://github.com/washingtonpost/data-police-shootings
#
# *What is the license of the dataset? What are we allowed to do with it?*
#
# https://github.com/washingtonpost/data-police-shootings/blob/master/LICENSE
# Noncommercial adaptive use is allowed.
#
# *How big is it in file size and in items?*
#
# 5763 rows x 17 columns, 627 KB (1 csv)
